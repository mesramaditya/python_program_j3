# %%
# file handling in python 
1. flie is acollection of information and stored in memory
2. files are 2 types `1.text file` and `2.binary file`
3.text file are `.txt, .py, .hmlt, .ipynb etc...
4.binary file are `.exe, .apk, .mp4 etc...

# %%
# files operations 
1.creat file - w mode 
2. write file - w mode 
3. read file - r mode 
4. append file - a mode

# %%
# creat a file using python script
create_file=open("profile. txt","w")
print("file created sucessfully in home direction")
create_file.close()
# Out:
# file created sucessfully in home direction

# %%
# write data to files using python script 
write_file=open("profile. txt","w")
data="welcome to texas international academy /learning python program"
write_file.write(data)
print("file created sucessfully and verify the proflie .txt file")
create_file.close()
# Out:
# file created sucessfully and verify the proflie .txt file

# %%
#read data from file using python script
