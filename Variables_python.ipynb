# %% [markdown]
# # Variables_in_Python
# 1. Variables is memory allocation to a value
# 2. examples are name="Ashvath" , age="17" , income=10000000
# # key points to define variables
# 1. Do not start with digit while creating variable
# 2. Does not allow special characters in a variables
# 3. Do not use key words in variables

# %%
name ="Vikas"
age = 22
salary = 10000
print(name)
print(age)
print(salary)
# Out:
# Vikas
# 22
# 10000

# %%
name = "Vikas"
print(name+' is a good boy')
# Out:
# Vikas is a good boy
