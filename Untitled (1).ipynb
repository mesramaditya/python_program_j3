# %%
# conditional statement in python
1. python have 4 types of conditional statements
2. `if` statement
3. `elifs` statement
4. `else` statement
5. `nested` statement

```python
if(condion):
    statement
    statement..
```

```python if,else
if(conditio):
    statement
    statement...
else:
    statement
    statement...
```

```python if,elif,else
if(condition):
    statement
elif(condition):
    statement
else(condition):
     statement..
```

# %%
#write a program to find the given number is even  number
num=int(input("please enter number here:"))
if(num%2 == 0):
    print(num,"is even number")
# Out:
# please enter number here: 83

# %%
num=int(input('please enter a number: '))
if (num%2 == 0):
        print(num,' is even number')
elif (num%2 == 1):
        print(num,' is odd numer')
# Out:
# please enter a number:  4
# 4  is even number

# %%
# write a program to find a number is positive , negetive or zero
number=int(input("please enter anumber here:"))
if (number>0):
    print(number,"is a positive number")
elif(number<0):
    print(number,"is a negitive number")
else:
    print(number,"is Neither positive nor negetive")
# Out:
# please enter anumber here: 0
# 0 is Neither positive nor negetive

# %%
"""
write a program to find the student grades based on marks
1. if student marks in between 100 to 80 then grade is A
2. if student marks in between 79 to 60 then grade is B
3. if student marks in between 59 to 40 then grade is C
4. if student marks in between 39 to 25 then grade is D
5. if student marks in between 24 to 0 then grade is fail
6. if other than about marks experted output  shoud be please enter correct marks!
"""
mark=int(input("Enter your marks: "))
if (mark >=80 and mark<=100):
    print(mark,"is A grade")
elif(mark>=60 and mark<=79):
    print(mark,"is B grade")
elif(mark>=40 and mark<=59):
    print(mark,"is C grade")
elif(mark>=25 and mark<39):
    print(mark,"is D grade")
elif(mark>=0 and mark<=24):
    print(mark," is fail grade")
else:
    print(marks<<"is not correct mark, please enter correct mark")
# Out:
# Enter your marks:  5
# 5  is fail grade

# %%
a=int(input("Enter 1st number: "))
b=int(input("Enter 2nd number: "))
c=int(input("Enter 3rd number: "))
if a >= b and a >= c:
    print(a," is the largest number")
elif b >= a and b >= c:
    print(b," is the largest number")
else:
    print(c," is the largest number")
# Out:
# Enter 1st number:  143
# Enter 2nd number:  341
# Enter 3rd number:  565
# 565  is the largest number

# %%
n=int(input("Enter a number: "))

if n%2 == 0 :
    if  (n>=1 and n<=9):
         print(n," is a 1 digit even number")
    elif (n>=10 and  n<=99):
         print(n," is a 2 digit even number")
    elif (n>=100 and n<=999):
        print(n," is a 3 digit even number")
    elif (n>=1000 and n<=9999):
         print(n," is a 4 digit even number")
    else :
        print(n," is a weierd even number")
else:
     print(n," is a odd number")
# Out:
# Enter a number:  44
# 44  is a 2 digit even number
