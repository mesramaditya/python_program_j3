# %% [markdown]
#  # functions in python
# 1. function in set of statement executed by calling the function name
# 2. functions are 2 types `1.pre defined functions and 2.user defined functions
# 3..pre defined functions are `print(), type(), list(), tuple(), dict(), int(), input() ...etc
# 3. .user defined functions created by user
# ``` python user defined functions
# def functions_name():
#     statement1..
#     statement n
# functions_name()
# ```

# %%
#inbuild functions
print("print the outputs")
print(sum([1,2,3,4,5,6,7]))
print(pow(2,6))
print(sorted([6,4,5,1,2,3,]))
print(dir(tuple))
print(help(list))
# Out:
# print the outputs
# 28
# 64
# [1, 2, 3, 4, 5, 6]
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'count', 'index']
# Help on class list in module builtins:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __delitem__(self, key, /)
# ...

# %%
# write a program to print addition of two strings using funtions 
def add_strings():
    a=str(input("enter first number:"))
    b=str(input("enter second number:"))
    result=a+b
    print(result)
    return result 
add_strings()
# Out:
# enter first number: pythonprograming
# enter second number: 'pythonprograming'
# pythonprograming'pythonprograming'
# "pythonprograming'pythonprograming'"

# %%
#write a program to print prifit using functions with arguments
def profile(neme,location,salary):
    print("my address is" ,location)
    print("my name is" ,name)
    print("my salary is" ,salary) 
profile(name="vikram",location="hydrabad",salary=50000)
profile(name="shiva",location="banglore",salary=100000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 6
#       4     print("my name is" ,name)
#       5     print("my salary is" ,salary)
# ----> 6 profile(name="vikram",location="hydrabad",salary=50000)
#       7 profile(name="shiva",location="banglore",salary=100000)
#
# TypeError: profile() got an unexpected keyword argument 'name'. Did you mean 'neme'?
