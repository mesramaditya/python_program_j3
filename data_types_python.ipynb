# %% [markdown]
# # data types in python
# 1. different vatype of values assinged to varible
# 2. basically 3 data types in python
# 3. int(integer)-numerical values like 1,2,3,4....
# 4. str(string)-characters examples "abcd","ghjk","querwy"
# 5. float(decimals)-numericals with decimals -10.25,23.6,23.8.......

# %%
name='vikas'
age=22
salary=10023.25
data='123'
print(name)
print(age)
print(salary)
print(data)
print(type(name))
print(type(age))
print(type(salary))
print(type(data))
# Out:
# vikas
# 22
# 10023.25
# 123
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
# concatentations
a=100
b=200
print(a+b)
# Out:
# 300

# %%
n1='python'
n2=' programming'
print(n1+n2)
# Out:
# python programming

# %%
a=100
b='200'
print(a+int(b))
# Out:
# 300
